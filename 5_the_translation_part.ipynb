# %% [markdown]
# ## Translating queries

# %% [markdown]
# In this notebook we translate the queries that we generated earlier, again using the API of Gemini.

# %%
import pandas as pd
import numpy as np

# %%
# load the dataframe that contains the queries

stratified_sample = pd.read_csv('data/stratified_sample_with_queries.csv')

# %%
master_prompt = """

You are a bilingual translator fluent in both English and Dutch.
Please translate each search query into the other language.

Provided search queries:
    English query: {text_en}
    Dutch query: {text_nl}

Only provide a response in the following format:
    Dutch translation: <Dutch translation>
    English translation: <English translation>

"""

# %%
# replace the previous formatted generation prompts with the new translation master_prompt that can be filled in with the right queries

stratified_sample['formatted_prompt'] = master_prompt

# %%
import time 
from google import genai
import google.generativeai as genai
import keys  # store your own api key in a file named keys.py

api_key = keys.GEMINI_API_KEY

if not api_key:
    raise ValueError("Gemini API key not found in keys.py.")

genai.configure(api_key=api_key)

# Select the Gemini model
model_name = "gemini-2.0-flash-lite"

model = genai.GenerativeModel(model_name)

# %%
# function fills in the prompt template with the search queries to be translated, and then prompts Gemini

def get_raw_response(text_en, text_nl, prompt_template):

    prompt = prompt_template.format(text_en=text_en, text_nl=text_nl)

    try:
        response = model.generate_content(prompt,
                                          generation_config = genai.types.GenerationConfig(temperature=0.2) 
        )
        return response 
    
    except Exception as e:
        print(f"Error in get_raw_response: {e}") 
        return None

# %%
# wrapper around get_raw_response function, to extract the translations from the raw Gemini response

def generate_translation(text_en, text_nl, prompt_template):
    "Extracts the translation from the raw Gemini response."

    if not text_en or not text_nl or pd.isna(text_en) or pd.isna(text_nl):  # ensure content is valid
        return "N/A"

    response = get_raw_response(text_en, text_nl, prompt_template)  # call the function

    if response is None:
        return "Error: No response from the API"  # handle the case where the API call failed

    # splitting the text based on "English translation:" and "Dutch translation:"
    try:
        raw_text = response.text.strip()
        print(raw_text)
        # splitting the text based on "English translation:" and "Dutch translation:"
        parts = raw_text.split("\n")  # first split by newline
        english_part = next((s for s in parts if "English translation:" in s), None)  # find line with "English translation:"
        dutch_part = next((s for s in parts if "Dutch translation:" in s), None)  # find line with "Dutch traslation:"

        if english_part and dutch_part:
            translation_en = english_part.replace("English translation:", "").strip()
            translation_nl = dutch_part.replace("Dutch translation:", "").strip()
            return (translation_en, translation_nl)
        else:
            return ("Error: Could not parse response", "Error: Could not parse response")

    except Exception as e:
        return str(e)  # return error message for debugging

# %%
# translate queries in both languages and put them in new columns

# empty lists to store the results
english_translations = []
dutch_translations = []

for idx, row in stratified_sample.iterrows():
    translation_en, translation_nl = generate_translation(row['query_en'], row['query_nl'], row['formatted_prompt'])
    english_translations.append(translation_en)
    dutch_translations.append(translation_nl)
    
    # sleep for 2 seconds to maintain max 30 requests/minute rate limit
    time.sleep(2)

# add the results to the dataframe
stratified_sample["translation_en"] = english_translations
stratified_sample["translation_nl"] = dutch_translations
# Out:
# Dutch translation: Een zuivelbedrijf bereidt zich voor om te bieden op een aanbesteding voor boter die door interventiebureaus wordt gehouden, en het bedrijf moet de prijsstructuur begrijpen. Specifiek is het bedrijf geïnteresseerd in de minimumverkoopprijs voor boter in de 35e individuele uitnodiging tot inschrijving die is uitgegeven in het kader van de permanente uitnodiging tot inschrijving. Het bedrijf moet de exacte minimumverkoopprijs per 100 kg weten, zoals bepaald door de relevante regelgeving, en de datum waarop de termijn voor het indienen van inschrijvingen is verstreken.
# English translation: A dairy company wants to submit a bid on a tender for butter held by intervention agencies, and the company needs to understand the pricing structure. Specifically, the company is interested in the minimum selling price for butter in the 35th individual invitation to tender issued under the standing invitation to tender. The company wants to know the exact minimum selling price per 100 kg as determined in the relevant regulation, and the date the deadline for submitting bids expired.
# Dutch translation: Een bedrijf importeert industriële producten uit Roemenië en wil de specifieke regelgeving voor deze handel begrijpen. Ze zijn met name geïnteresseerd in het weten of er nieuwe producten van Roemeense oorsprong zijn toegevoegd aan de lijst van geliberaliseerde producten op Gemeenschapsniveau, en zo ja, wanneer deze wijzigingen van kracht zijn geworden. Het bedrijf moet de exacte datum weten waarop de Commissiebeslissing met betrekking tot deze toevoegingen van toepassing is om te voldoen aan de laatste handelsregels. Wat is de datum waarop de Commissiebeslissing tot wijziging van Verordening (EEG) nr. 3419/83, tot uitbreiding van de lijst van producten van oorsprong uit Roemenië die op Gemeenschapsniveau zijn geliberaliseerd, van toepassing is?
# English translation: An importer of industrial products from Romania wants to understand the most recent trade regulations. The importer wants to know if any new products of Romanian origin have been added to the list of liberalized products at Community level. The importer wants to know the exact date on which the Commission Decision regarding these additions came into effect in order to comply with the latest trade regulations. What is the date on which the Decision amending Regulation (EEC) No. 3419/83 by extending the list of products originating in Romania which have been liberalized at Community level, applies?
# Dutch translation: Wijzigt de Commissie Verordening (EU) Nr. 666/2010 van 23 juli 2010 de representatieve prijzen en aanvullende invoerrechten voor bepaalde producten in de suikersector die zijn vastgesteld door Verordening (EG) Nr. 877/2009 voor het verkoopseizoen 2009/10, zoals vermeld in de titel ervan?
# English translation: Does Commission Regulation (EU) No 666/2010 of 23 July 2010 amend the representative prices and additional import duties for certain products in the sugar sector that were fixed by Regulation (EC) No 877/2009 for the 2009/10 marketing year, as stated in its title?
# Dutch translation: Een Canadese importeur van groenten en fruit maakt zich zorgen over mogelijke wijzigingen van de tarieven op groenten en fruit. Ze proberen de geschiedenis van de handelsovereenkomsten tussen Canada en de Europese Economische Gemeenschap te begrijpen, met name de rol van de Algemene Overeenkomst betreffende Tarieven en Handel bij het vormgeven van deze overeenkomsten, en zijn op zoek naar details over de specifieke producten die onder een dergelijke overeenkomst vallen. Kan iemand informatie verstrekken over de producten die het onderwerp waren van een overeenkomst tussen de EEG en Canada, en de juridische basis voor die overeenkomst?
# English translation: A Canadian produce importer is concerned about potential changes to tariffs on fruits and vegetables. They are trying to understand the history of trade agreements between Canada and the European Economic Community, specifically focusing on the role of the General Agreement on Tariffs and Trade in shaping these agreements, and are looking for details about the specific products covered by any such agreement. Can anyone provide information on the products that were subject to an agreement between the EEC and Canada, and the legal basis for that agreement?
# Dutch translation: Welk specifiek chemisch product, aangeduid met zijn Common Customs Tariff-onderverdeling en land van oorsprong, had de douanerechten hersteld voor import in de Europese Gemeenschap, en op welke datum trad deze herinstelling van rechten in werking volgens de Commissieverordening?
# English translation: What specific chemical product, identified by its Common Customs Tariff subheading and country of origin, had customs duties re-established for imports into the European Community, and on what date did this re-establishment of duties take effect according to the Commission Regulation?
# Dutch translation: Welke specifieke landbouwproducten worden genoemd in de context van standaard invoerwaarden en de toepassing van een bepaalde verordening betreffende groenten en fruit, volgens het document van 10 mei 2012?
# English translation: What specific vegetables and fruits are mentioned in connection with the standard import values and the application of a certain regulation, according to the document of May 10, 2012?
# Dutch translation: Een pluimveehouder in het Verenigd Koninkrijk maakt zich zorgen over de mogelijke uitbraak van vogelgriep, met name de H5N1-stam, en is op de hoogte van eerdere EU-maatregelen. Ze willen inzicht in het huidige juridische kader met betrekking tot de duur van de bestaande bioveiligheidsmaatregelen die zijn ontworpen om pluimvee en andere in gevangenschap gehouden vogels tegen het virus te beschermen, en of er recente wijzigingen zijn aangebracht in de data waarop deze maatregelen van kracht zijn, en wat de nieuwe einddatum is. Ze zijn ook geïnteresseerd om te weten of er specifieke eisen zijn voor gezelschapsvogels die het VK binnenkomen, en of die eisen recentelijk zijn bijgewerkt.
# English translation: A poultry farmer in the Netherlands is concerned about the potential for avian influenza outbreaks, particularly the H5N1 strain, and is aware of previous EU measures. They want to understand the current legal framework regarding the duration of existing biosecurity measures designed to protect poultry and other captive birds from the virus, and if there have been any recent changes to the dates these measures are in effect, and what the new end date is. They are also interested in knowing if there are any specific requirements for pet birds entering the Netherlands, and if those requirements have been updated recently.
# Dutch translation: Heeft de Engelse zoekopdracht betrekking op een Raadsverordening van maart 1997 over een overeenkomst tussen de Europese Gemeenschap en Cyprus, die de invoerregeling voor sinaasappelen van oorsprong uit Cyprus wijzigde, en zo ja, of daarbij ook een eerdere verordening betreffende tariefcontingenten voor producten uit verschillende landen werd gewijzigd?
# English translation: Did the Dutch search query concern a Council Regulation from March 1997 about an agreement between the European Community and Cyprus, that amended the import regime for oranges originating in Cyprus, and if so, whether a previous regulation concerning tariff quotas for products from various countries was also amended?
# Dutch translation: Wat is de maximum communautaire bijdrage, in miljoen EUR, voor de financiering van de werkprogramma's opgesteld door gecertificeerde operators in de olijfoliesector voor Griekenland, Frankrijk en Italië, volgens deze verordening?
# English translation: What is the maximum Community contribution, in EUR million, to financing the work programmes drawn up by certified operators in the olive oil sector for Greece, France, and Italy, according to this regulation?
# Dutch translation: Een fruit- en groenteproducentenorganisatie in de EU ondervindt vertraging bij het ontvangen van financiële steun voor hun operationeel programma dat in 2012 is geïmplementeerd, als gevolg van een juridische uitdaging met betrekking tot de berekening van de waarde van de verhandelde productie. Gezien de potentiële impact van deze vertragingen op hun cashflow en operationele planning, wat is de laatste datum waarop lidstaten de financiële steun van de Unie voor deze programma's, specifiek die met betrekking tot groenten en fruit bestemd voor verwerking, mogen uitbetalen?
# English translation: A fruit and vegetable producer organization in the EU is experiencing delays in receiving financial aid for their operational program implemented in 2012, due to a legal challenge concerning the calculation of the value of marketed production. Considering the potential impact of these delays on their cash flow and operational planning, what is the latest date by which Member States are allowed to pay the Union financial assistance for these programs, specifically those related to fruit and vegetables intended for processing?
# Dutch translation: Welke specifieke acties heeft de Europese Commissie op 28 februari 2011 ondernomen met betrekking tot de vaststelling van de invoerprijzen voor geïmporteerd fruit en groenten, en welke wettelijke basis gebruikten ze om deze acties te rechtvaardigen?
# English translation: What specific actions did the European Commission take on February 28th, 2011, concerning the determination of entry prices for imported fruits and vegetables, and what legal basis did they use to justify these actions?
# Dutch translation: Maximum export refund for common wheat January 2002?
# English translation: Maximum export refund for soft wheat January 2002?
# Dutch translation: Wat is de datum waarop de uitvoerrestituties voor olijfolie, zoals vastgesteld in Verordening (EG) nr. 1483/2005 van de Commissie, van kracht worden en wanneer wordt deze verordening bindend en rechtstreeks toepasselijk in alle lidstaten?
# English translation: What is the date that the Commission Regulation (EC) No 1483/2005, determining the export refunds on olive oil, will come into effect and when will this regulation be binding and directly applicable in all Member States?
# Dutch translation: Een vleesimporteur die van plan is hoogwaardig rund- en kalfsvlees uit de Verenigde Staten en Canada te importeren, is op de hoogte van een tariefcontingentensysteem en wil de specifieke procedures en tijdschema's begrijpen voor het verkrijgen van de benodigde importvergunningen. Ze zijn met name geïnteresseerd in de beschikbaarheid van vergunningen en de toegestane hoeveelheden. Kunnen ze informatie vinden over de aanvraagperiodes en de hoeveelheid rund- en kalfsvlees die onder speciale voorwaarden kan worden geïmporteerd, en wat zijn de relevante voorschriften?
# English translation: A meat importer wants to import high-quality beef, fresh, chilled or frozen, and is looking for information about the import of beef from the United States and Canada. The importer is familiar with a tariff quota system and wants to understand the specific procedures and deadlines for obtaining the necessary import certificates. The importer is specifically interested in the availability of certificates and the permitted quantities. Can the importer find information about the application periods and the amount of beef that can be imported under special conditions, and what relevant regulations apply?
# Dutch translation: Welke specifieke toewijzingscoëfficiënt, indien van toepassing, wordt toegepast op de hoeveelheden die zijn aangevraagd voor invoercertificaataanvragen voor rijst in het kader van het quotum met bestelnummer 09.4138, zoals vermeld in Verordening (EG) nr. 327/98, als die aanvragen zijn ingediend in de eerste tien werkdagen van oktober 2008?
# English translation: What specific allocation coefficient, if any, is applied to the quantities requested for import certificate applications for rice under the quota with order number 09.4138, as referred to in Regulation (EC) No 327/98, if those applications were lodged in the first ten working days of October 2008?
# Dutch translation: Is fishing for herring by Danish vessels prohibited after 3 November 2001?
# English translation: Is visserij op haring door Deense vaartuigen verboden vanaf November 3, 2001?
# Dutch translation: Is fishing for redfish in NAFO area 3LN by vessels flying the flag of a European Union Member State prohibited due to the exhaustion of a specific quota allocated for the year 2013, according to a regulation published in December 2013?
# English translation: Has fishing for redfish in NAFO area 3LN by vessels flying the flag of a European Union Member State been prohibited due to the exhaustion of a specific quota allocated for the year 2013, according to a regulation published in December 2013?
# Dutch translation: Wijzigt deze regulation de catch mogelijkheden voor 1987?
# English translation: Does this regulation amend the catch possibilities for 1987?
# Dutch translation: Een bedrijf heeft een specifiek type product geïmporteerd en heeft bindende tariefinlichtingen ontvangen van de douane van een lidstaat met betrekking tot de classificatie ervan onder de Gecombineerde Nomenclatuur. Het bedrijf is echter nu op de hoogte van een recente verordening betreffende de classificatie van goederen die in tegenspraak lijkt te zijn met de eerder afgegeven bindende tariefinlichtingen. Het bedrijf moet de implicaties van deze nieuwe verordening begrijpen voor de geldigheid en het gebruik van de bestaande bindende tariefinlichtingen, rekening houdend met de mogelijke impact op de invoerrechten en handelspraktijken. Wat zijn de specifieke voorwaarden en termijnen die van toepassing zijn op het voortgezette gebruik van de bindende tariefinlichtingen in dit scenario?
# English translation: A company has imported a specific type of product and has received binding tariff information from a member state's customs authorities regarding its classification under the Combined Nomenclature. However, the company is now aware of a recent regulation concerning the classification of goods that appears to contradict the previously issued binding tariff information. The company needs to understand the implications of this new regulation on the validity and use of the existing binding tariff information, considering the potential impact on its import duties and trade practices. What are the specific conditions and timeframes that apply to the continued use of the binding tariff information in this scenario?
# Dutch translation: Welke belastingen financieren de research aids?
# English translation: Which taxes finance the research aids?
# Dutch translation: Is EPPO quarantaineprocedure nr. 26 vervangen?
# English translation: Is EPPO quarantine procedure No. 26 replaced?
# Dutch translation: Finland steunlimieten voor levende planten en bloementeeltproducten.
# English translation: Finland aid for live plants and floriculture area.
# Dutch translation: Welke specifieke waarden zijn vastgelegd in de bijlage bij Uitvoeringsverordening (EU) nr. 1237/2014 van de Commissie, en wat is de rechtsgrondslag voor deze waarden, volgens het document, betreffende de invoer van bepaalde groenten en fruit?
# English translation: What are the fixed import values established in the Annex to Commission Implementing Regulation (EU) No 1237/2014, and what is the legal basis for these values, according to the document, concerning the import of certain fruit and vegetables?
# Dutch translation: Stelt deze verordening importwaarden vast voor groenten en fruit?
# English translation: Does this regulation establish flat-rate import values?
# Dutch translation: Wat is de maximum export refund, in EUR per 100 kg, voor witte suiker naar bepaalde derde landen, en op welke specifieke deelinschrijving is deze restitutie van toepassing, volgens de Commissieverordening van 19 februari 2004, en op welke verordening is dit gebaseerd?
# English translation: What is the maximum export refund, in EUR per 100 kg, for white sugar to certain third countries, and which specific partial invitation to tender does this refund apply to, according to the Commission Regulation issued on February 19, 2004, and what regulation is this based on?
# Dutch translation: Welke specifieke hoeveelheden rundvlees met bot, in bezit van welke interventie-instanties, worden te koop aangeboden, en wat zijn de belangrijkste voorwaarden en deadlines voor deze verkoop, inclusief de vereiste zekerheidsbedragen en de uitvoerterkader?
# English translation: What quantities of bone-in beef, held by which intervention agencies, are being offered for sale, and what are the key conditions and deadlines for this sale, including the required security amounts and the export timeframe?
# Dutch translation: Wat zijn de respectieve budgettaire plafonds, in ton, vastgesteld op basis van de referentiehoeveelheden voor de periode van 12 maanden 1999/2000 voor Duitsland en Oostenrijk, volgens Verordening (EG) nr. 2217/2004 van de Raad?
# English translation: What are the respective total amounts, in tonnes, that have been fixed on the basis of the reference quantities for the 12-month period 1999/2000 for Germany and Austria, according to Council Regulation (EC) No 2217/2004?
# Dutch translation: Een bedrijf in het Verenigd Koninkrijk importeert houten verpakkingsmateriaal uit China voor zijn producten en maakt zich zorgen over de mogelijke vertraging of weigering van hun zendingen vanwege de regelgeving met betrekking tot de introductie van het organisme Anoplophora glabripennis (Motschulsky). Ze willen weten welke specifieke eisen van toepassing zijn op hout afkomstig uit China, met uitzondering van Hong Kong, dat wordt gebruikt voor verpakking en ondersteuning, en of er een datum is waarna deze eisen van kracht zijn, zodat ze aan de voorschriften kunnen voldoen en problemen met de douane of inspecties kunnen voorkomen.
# English translation: A Dutch company is importing wooden packaging material from China and is concerned about the possible delay or rejection of their shipments due to regulations regarding the introduction of the organism Anoplophora glabripennis (Motschulsky). They want to know what specific requirements apply to wood originating from China, excluding Hong Kong, that is used for packaging and support, and if there is a date after which these requirements are in effect, so they can comply with the regulations and avoid problems with customs or inspections.
# Dutch translation: Voldoet de Engelse zoekopdracht: "Does the Grand-Ducal Regulation of 27 May 1988 laying down the detailed rules for allocating the annual compensatory allowance to farmers, forwarded by the Luxembourg government in accordance with Article 24 (4) of Regulation (EEC) No 797/85, satisfy the conditions for a financial contribution from the Community to the common measure provided for in Article 1 of Regulation (EEC) No 797/85?"
#
# English translation: Does the Dutch search query: "Voldoet de door de Luxemburgse regering overeenkomstig artikel 24, lid 4, van verordening (EEG) nr. 797/85 meegedeelde verordening van het Groothertogdom van 27 mei 1988 tot vaststelling van de voorwaarden voor toekenning van de jaarlijkse compenserende vergoeding aan landboubedrijfshoofden aan de voorwaarden voor financiële deelneming van de Gemeenschap aan de in artikel 1 van verordening (EEG) nr. 797/85 bedoelde gemeenschappelijke actie?" satisfy the conditions for a financial contribution from the Community to the common measure provided for in Article 1 of Regulation (EEC) No 797/85?
# Dutch translation: Een pluimveehouder in Frankrijk maakt zich zorgen over mogelijke uitbraken van vogelgriep en wil weten of er financiële steun beschikbaar is vanuit de Europese Gemeenschap ter ondersteuning van de uitvoering van onderzoeken naar vogelgriep bij pluimvee. Specifiek, welk percentage van de kosten die de lidstaten maken voor deze onderzoeken worden door de Gemeenschap gedekt, en wat is het maximale totale bedrag aan financiële bijdrage dat de Gemeenschap in totaal aan alle lidstaten verstrekt?
# English translation: A poultry farmer in the Netherlands wants to know if there is financial assistance available from the European Community for conducting research into avian influenza in poultry. The poultry farmer is curious about what percentage of the costs incurred by the Member States for these surveys are reimbursed by the Community, and what is the maximum total amount of financial contribution that the Community provides to all Member States combined.
# Dutch translation: Visverbod op kabeljauw voor Duitse schepen in EG wateren?
# English translation: Fishing ban for cod in Germany?
# Dutch translation: Welke percentage van de financiële bijdrage heeft de Commissie besloten te verlenen voor de aankoop van data-verwerkingsapparatuur en voor de specifieke operaties die zijn ondernomen om een register van de vissersvloot op te zetten, volgens het document?
# English translation: What financial contribution did the Commission decide to provide for the purchase of data-processing hardware and for the specific operations undertaken to establish a register of the fishing fleet, according to the document?
# Dutch translation: Eisen voor motorvoertuigen betreffende uitstekende delen vóór de cabine?
# English translation: Requirements for motor vehicles regarding external projections forward of the cab?
# Dutch translation: Een Pools visserijbedrijf dat actief is in NAFO-zone 3L is geïnformeerd dat hun vangsten van noordse garnaal aanzienlijk zijn geweest. Ze maken zich zorgen over mogelijke juridische gevolgen. Welke acties zijn verboden voor vaartuigen die de Poolse vlag voeren, of in Polen geregistreerd zijn, met betrekking tot de visserij op noordse garnaal in NAFO-zone 3L, en vanaf welke datum worden deze verboden van kracht, volgens relevante regelgeving? Het bedrijf moet de specifieke beperkingen en de exacte datum waarop deze van toepassing zijn begrijpen om naleving te garanderen en boetes te voorkomen.
# English translation: A Polish fishing company operating in NAFO zone 3L has been informed that their catches of northern shrimp have been substantial. They are concerned about potential legal repercussions. What actions are prohibited for vessels flying the Polish flag, or registered in Poland, regarding the fishing of northern shrimp in NAFO zone 3L, and from what date do these prohibitions become effective, according to relevant regulations? The company needs to understand the specific restrictions and the exact date from which they apply to ensure compliance and avoid penalties.
# Dutch translation: Wat is gewijzigd in artikel 1(2) van Verordening 1091/94?
# English translation: What is changed in Article 1, paragraph 2, of Regulation 1091/94?
# Dutch translation: Een bedrijf dat gewasbeschermingsmiddelen produceert die de werkzame stof cinidon-ethyl bevat, is op de hoogte van het feit dat de goedkeuring van de stof afloopt. Ze zijn onzeker over de gevolgen hiervan en moeten de deadlines en eventuele respijtperioden begrijpen die van toepassing kunnen zijn op hun bestaande voorraad en distributie van deze producten. Specifiek, wat zijn de uiterste data waarop ze bestaande voorraden van gewasbeschermingsmiddelen die cinidon-ethyl bevatten, kunnen verkopen, distribueren, verwijderen, opslaan of gebruiken, en welke wettelijke basis ondersteunt deze deadlines?
# English translation: A company that manufactures plant protection products containing the active substance cinidon-ethyl is aware that the substance's approval is expiring. They are unsure about the implications of this and need to understand the deadlines and any potential grace periods that might apply to their existing stock and distribution of these products. Specifically, what are the latest dates by which they can sell, distribute, dispose of, store, or use existing stocks of plant protection products containing cinidon-ethyl, and what legal basis supports these deadlines?
# Dutch translation: Wanneer zal de Commissie een rapport indienen?
# English translation: When does the Commission submit a report?
# Dutch translation: Wat is de datum waarop de Commission Regulation (EC) No 2317/97 betreffende de landennomenclatuur voor de statistieken van de buitenlandse handel van de Gemeenschap en de handel tussen de lidstaten van toepassing zal zijn, volgens het document?
# English translation: What is the date that Commission Regulation (EC) No 2317/97 on the country nomenclature for external trade statistics of the Community and trade between Member States will begin to be applied, according to the document?
# Dutch translation: Een boer in de "secano"-regio van Spanje overweegt compensatie aan te vragen voor akkerbouwgewassen. Ze overwegen ook grond braak te leggen in een andere opbrengstregio dan waar hun in aanmerking komende gewassen zich bevinden. Welke specifieke voorwaarden, indien van toepassing, moeten worden voldaan met betrekking tot de locatie van de braakliggende grond en eventuele aanpassingen van de braakliggende oppervlakte, volgens de relevante regelgeving?
# English translation: A farmer in the "secano" region of Spain is considering applying for compensatory payments for arable crops. They are also considering setting aside land in a different yield region than where their eligible crops are located. What specific conditions, if any, must be met regarding the location of the set-aside land and any adjustments to the set-aside area, according to the relevant regulations?
# Dutch translation: Is de prijs voor vlas verlaagd als er ander bindtouw wordt gebruikt?
# English translation: Is the price of flax reduced when other binder twine is used?
# Dutch translation: Een bedrijf dat gespecialiseerd is in bananenimport, gecategoriseerd als een niet-traditionele operator, heeft een aanvraag ingediend voor een toewijzing in het kader van de tariefcontingenten A/B voor het jaar 2003. Het bedrijf wil graag begrijpen hoe de totale toewijzing aangevraagd door alle niet-traditionele operators hun individuele toewijzing zal beïnvloeden. Specifiek, welk percentage van hun aangevraagde toewijzing zal het bedrijf daadwerkelijk ontvangen, rekening houdend met de totale hoeveelheid aangevraagd door alle A/B operators en de relevante regelgeving betreffende bananenimport?
# English translation: A banana import company, categorized as a non-traditional market participant, has submitted an application for an allocation under the tariff quotas A/B for the year 2003. The company wants to know how the total amount requested by all non-traditional market participants affects their individual allocation. What percentage of the amount requested by the company will the company actually receive, taking into account the total amount requested by all A/B market participants and the relevant regulations regarding banana imports?
# Dutch translation: Maximum aid for olive oil private storage and allocation coefficient.
# English translation: Maximum support amount olive oil private storage and allocation coefficient.
# Dutch translation: Een voedselimporteur probeert de kosten te berekenen die gepaard gaan met het importeren van suikerproducten van buiten de Europese Gemeenschap. Ze zijn zich ervan bewust dat er representatieve prijzen en aanvullende rechten van toepassing zijn, maar ze moeten weten of er recente wijzigingen in deze cijfers zijn doorgevoerd. Ze zijn specifiek geïnteresseerd in het weten of de representatieve prijzen en aanvullende rechten voor witte suiker, ruwe suiker en bepaalde siropen recentelijk zijn bijgewerkt, en zo ja, wanneer de wijzigingen van kracht zijn geworden.
# English translation: A food importer is trying to calculate the costs associated with importing sugar products from outside the European Community. They are aware that representative prices and additional duties apply, but they need to know if any recent changes have been made to these figures. Specifically, they are interested in knowing if the representative prices and additional duties for white sugar, raw sugar, and certain syrups have been updated recently, and if so, when the changes came into effect.
# Dutch translation: Een bedrijf dat vlas- en hennepvezels verwerkt, heeft moeite om de limiet van 7,5% onzuiverheden en scheven voor korte vezels te halen, en maakt zich zorgen over de gevolgen voor hun subsidiabiliteit voor verwerkingssteun. Ze zijn zich ervan bewust dat er enige flexibiliteit in de regels zou kunnen zijn. Ze zoeken informatie over de vraag of lidstaten verwerkingssteun kunnen verlenen voor vlas- en hennepvezels met hogere onzuiverheidsniveaus, specifiek of er een mogelijkheid is tot afwijking van de 7,5% limiet, en zo ja, hoe lang deze afwijking is toegestaan, en wat de acceptabele onzuiverheidsniveaus zijn voor elk vezeltype.
# English translation: A company processing flax and hemp fibers is struggling to meet the 7.5% impurity and shive limit for short fibers, and is concerned about the impact on their eligibility for processing aid. They are aware that there might be some flexibility in the rules. They are looking for information on whether Member States can grant processing aid for flax and hemp fibers with higher impurity levels, specifically if there is a possibility for derogation from the 7.5% limit, and if so, for how long this derogation is allowed, and what the acceptable impurity levels are for each fiber type.
# Dutch translation: Welke specifieke actie is ondernomen door de Commissie van de Europese Gemeenschappen op 26 juni 1987 met betrekking tot de prijs van onbewerkte krenten van de oogst 1985 bestemd voor de vervaardiging van bepaalde kruiderijen, en wat is de juridische basis voor deze actie, met vermelding van relevante Raadverordeningen?
# English translation: What specific measure did the Commission of the European Communities take on June 26, 1987, regarding the price of unprocessed currants from the 1985 harvest intended for the manufacture of certain condiments, and what is the legal basis for this measure, referencing relevant Council Regulations?
# Dutch translation: Welke veranderingen zijn doorgevoerd in de tariefcontingenten voor producten afkomstig uit Chili, specifiek met betrekking tot de volumes en toepassingsdata, als gevolg van de wijziging van Verordening (EG) nr. 312/2003?
# English translation: What adjustments were made to the tariff quotas for products originating from Chile, specifically regarding the volumes and application dates, as a result of the amendment to Regulation (EC) No 312/2003?
# Dutch translation: Welke specifieke wisselkoers, vastgesteld in een verordening van maart 2006, is van toepassing op bedragen gerelateerd aan structurele of milieumaatregelen, en wat is de basis voor het bepalen van de timing waarop deze wisselkoers moet worden gebruikt?
# English translation: What exchange rate, determined in a regulation from March 2006, should be specifically applied to amounts related to structural or environmental measures, and what is the basis for determining the timing of when this exchange rate should be used?
# Dutch translation: Welke specifieke datum trad de Europese Commissie verordening betreffende standaard invoerwaarden voor het bepalen van de toegangsprijs van bepaalde groenten en fruit, zoals vermeld in het document, officieel in werking?
# English translation: On what date did the Commission's regulation establishing standard import values for determining the entry price of certain fruits and vegetables, as mentioned in the document, officially come into effect?
# Dutch translation: Were there any other substances mentioned in this document, besides clopyralid, cyprodinil, fosetyl and trinexapac, for which further tests are needed to confirm the risk assessment?
# English translation: Were there any specific substances, besides clopyralid, cyprodinil, fosetyl and trinexapac, mentioned in the document that would require further testing for confirmation of risk assessment?
# Dutch translation: Wordt in de tekst van "COMMISSIE UITVOERINGSVERORDENING (EU) Nr. 1041/2013 van 24 oktober 2013" expliciet vermeld dat de in artikel 136 van Uitvoeringsverordening (EU) nr. 543/2011 genoemde standaard invoerwaarden in een bijlage bij deze verordening zijn vastgelegd?
# English translation: Does the text of "COMMISSION IMPLEMENTING REGULATION (EU) No 1041/2013 of 24 October 2013" explicitly state that the standard import values referred to in Article 136 of Implementing Regulation (EU) No 543/2011 are fixed in an annex to this regulation?
# Dutch translation: Was Verordening (EEG) nr. 643/77 ingetrokken?
# English translation: Is Regulation (EEC) No 643/77 repealed?
# Dutch translation: Heeft het Parlement kwijting verleend voor 1984 accounts?
# English translation: Did Parliament grant discharge for 1984?
# Dutch translation: Een suikerfabrikant die zich voorbereidt om een offerte in te dienen voor de export van witte suiker naar een derde land, is op de hoogte van een permanente aanbesteding uitgegeven onder Verordening (EG) nr. 1290/2003 en neemt deel aan de 20e gedeeltelijke aanbesteding. De exporteur wil weten wat de maximale restitutie bij uitvoer is die ze kunnen claimen voor hun witte suikerexport naar deze specifieke derde landen, aangezien dit van invloed is op hun winstgevendheid. Wat is de maximale restitutie per 100 kg witte suiker die geclaimd kan worden onder de 20e gedeeltelijke aanbesteding, en wat is de juridische basis voor deze restitutie?
# English translation: A sugar manufacturer preparing to submit a tender for the export of white sugar to a third country is aware of a standing invitation to tender issued under Regulation (EC) No 1290/2003 and is participating in the 20th partial invitation to tender. The exporter wants to know the maximum export refund they can claim for their white sugar exports to these specific third countries, as this impacts their profitability. What is the maximum refund per 100 kg of white sugar that can be claimed under the 20th partial invitation to tender, and what is the legal basis for this refund?
# Dutch translation: Welke bloemen hebben gemeenschappelijke producenten- en importprijzen?
# English translation: What flowers have community producer and import prices?
# Dutch translation: Wat is het goedgekeurde gebruik van koolstofdioxide in deze richtlijn?
# English translation: What is carbon dioxide approved for in this directive?
# Dutch translation: Een vertegenwoordiger van een producerende lidstaat is verantwoordelijk voor het beheer van olijfolievoorraden en moet inzicht krijgen in de rapportageverplichtingen aan de Commissie met betrekking tot interventiemaatregelen. Ze zijn op de hoogte van een eerdere verordening betreffende de mededelingen tussen de lidstaten en de Commissie over oliën en vetten, maar zijn onzeker over de specifieke rapportagevereisten voor de voorgaande maand. Welke specifieke informatie moet de producerende lidstaat aan de Commissie verstrekken, en voor welke deadline, met betrekking tot interventiemaatregelen zoals bedoeld in artikel 12 van Verordening nr. 136/66/EEG, volgens de geactualiseerde regelgeving?
# English translation: A representative from a producing Member State is responsible for managing olive oil stocks and needs to understand their reporting obligations to the Commission regarding intervention measures. They are aware of a previous regulation concerning communications between the Member States and the Commission on oils and fats, but are unsure about the specific reporting requirements for the previous month. What specific information must the producing Member State provide to the Commission, and by what deadline, concerning intervention measures as referred to in Article 12 of Regulation No 136/66/EEC, according to the updated regulations?
# Dutch translation: Welke wijzigingen zijn er doorgevoerd aan het diervoederadditief Bacillus subtilis DSM 17299?
# English translation: What changes were implemented for the Bacillus subtilis DSM 17299 feed additive?
# Dutch translation: Hoe is de hulp voor durumtarwe buiten traditionele zones beïnvloed?
# English translation: How is support for durum wheat affected outside traditional zones?
# Dutch translation: Wanneer moet tafelwijn aan een distilleerderij geleverd worden?
# English translation: When must table wine be delivered to a distillery?
# Dutch translation: Welke inrichtingen zijn bevoegd om gelatine voor menselijke consumptie te importeren?
# English translation: Which establishments are authorized to import gelatine for human consumption?
# Dutch translation: Levert de Gemeenschap Albanië van granen?
# English translation: Does the Community supply Albania with cereals?
# Dutch translation: Welke specifieke soorten producten vallen binnen de productgroep "textielproducten" zoals gedefinieerd in de Commissiebeslissing van 17 februari 1999, en welke criteria worden gebruikt om de milieuprestaties en de geschiktheid voor gebruik van deze producten te beoordelen, rekening houdend met de geldigheidsduer van de productgroepdefinitie en de criteria?
# English translation: What specific types of products are included within the product group "textile products" as defined in the Commission Decision of February 17, 1999, and what criteria are used to assess the environmental performance and fitness for use of these products, considering the validity period of the product group definition and the criteria?
# Dutch translation: Welke specifieke informatiebronnen moeten worden gebruikt bij het bepalen van de franco-grens prijzen voor karper, volgens de verordening die op 25 juli 1974 is aangenomen, en welke soorten informatie verschaffen deze bronnen?
# English translation: What sources are primarily used for collecting data to determine free-at-frontier prices for carp, and what types of information do these sources publish according to the regulation of July 25, 1974?
# Dutch translation: Welke specifieke internationale overeenkomsten met betrekking tot onderzoek naar gecontroleerde thermonucleaire fusie en plasmafysica werden gewijzigd, en welke landen waren betrokken bij deze wijzigingen, volgens een Raadsbesluit van 26 april 1982?
# English translation: Which countries and which specific cooperation agreements in the field of controlled thermonuclear fusion and plasma physics were amended, and which parties were involved in these amendments, according to a Council Decision from April 26, 1982?
# Dutch translation: Heeft de Raad de overeenkomst goedgekeurd?
# English translation: Did the agreement get approved by the Council?
# Dutch translation: Wanneer treedt Commission Regulation (EC) No 818/2002 in werking?
# English translation: When does Regulation (EC) No. 818/2002 enter into force?
# Dutch translation: Welke specifieke landen, naast de Europese Economische Gemeenschap, waren betrokken bij de Overeenkomst betreffende de uitwisseling van informatie op het gebied van technische voorschriften, en wat was het voornaamste doel van de Vrijhandelsovereenkomsten met die landen?
# English translation: What specific countries, besides the European Economic Community, were involved in the Agreement concerning the exchange of information in the field of technical regulations, and what was the primary aim of the Free Trade Agreements with those countries?
# Dutch translation: Wat is er gebeurd met de nieuwe exporteur review van wijnsteenzuur?
# English translation: What is the outcome of the new investigation into tartaric acid?
# Dutch translation: Een vleesimporteur bereidt zich voor om bevroren rund- en kalfsvleessneden, specifiek "crop", "chuck and blade" en "brisket", in een lidstaat te importeren. Ze moeten weten welk specifiek document aan de douaneautoriteiten moet worden overgelegd om de invoer van deze bevroren vleesproducten toe te staan, en wat is de specifieke naam van dit document dat moet worden overgelegd om te voldoen aan de eisen voor de toelating van dit type bevroren vlees onder de gemeenschappelijke douanetariefpost 02.01 A II b) 4 bb) 22.
# English translation: A meat importer is planning to import frozen beef and veal cuts, specifically "crop", "chuck and blade" and "brisket", into a member state. They need to know what specific document must be presented to the customs authorities to allow the import of these frozen meat products, and what is the specific name of this document that must be submitted to meet the requirements for the admission of this type of frozen meat under the Common Customs Tariff subheading 02.01 A II b) 4 bb) 22.
# Dutch translation: Wordt in de Commissieverordening (EG) nr. 2337/2002, tot wijziging van Verordening (EG) nr. 1555/96 betreffende aanvullende invoerrechten voor groenten en fruit, specifiek de wijziging van de drempelwaarden voor aanvullende rechten op courgettes, citroenen, appels en peren vermeld, gebaseerd op gegevens uit de jaren 1999, 2000 en 2001?
# English translation: Does Commission Regulation (EC) No 2337/2002, which amends Regulation (EC) No 1555/96 regarding additional import duties on fruit and vegetables, specifically mention the amendment of the trigger levels for additional duties on courgettes, lemons, apples, and pears, based on data from the years 1999, 2000, and 2001?
# Dutch translation: Welke goederen worden gecontroleerd in het Council Decision van 16 februari 1996?
# English translation: What goods are controlled in the Council Decision of 16 February 1996?
# Dutch translation: Wijzigt deze regulation Verordening (EEG) nr. 223/90?
# English translation: Does this regulation amend Regulation (EEC) No 223/90?
# Dutch translation: Total aid amount authorized for Belgian coal industry in 1987?
# English translation: Totaal steunbedrag voor Belgische kolenindustrie in 1987?
# Dutch translation: Een in het Verenigd Koninkrijk gevestigde elektronicaverkoper maakt zich zorgen over mogelijke btw-fraude en zoekt informatie over maatregelen die van kracht zouden kunnen zijn om dit te voorkomen, met name met betrekking tot de verkoop van mobiele telefoons. Ze proberen te begrijpen of er speciale regels zijn over wie verantwoordelijk is voor het betalen van btw op bepaalde transacties met een hoge waarde, en zo ja, wat de minimale transactiewaarde is om deze regels te activeren. Kan iemand het drempelbedrag verduidelijken voor leveringen van mobiele telefoons die onder een verleggingsregeling zouden vallen?
# English translation: A UK-based electronics retailer is concerned about potential VAT fraud and is looking for information on measures that might be in place to prevent it, specifically regarding the sale of mobile phones. They are trying to understand if there are any special rules about who is responsible for paying VAT on certain high-value transactions, and if so, what the minimum transaction value is to trigger these rules. Can someone clarify the threshold amount for supplies of mobile phones that would be subject to a reverse charge mechanism?
# Dutch translation: Is deze richtlijn van toepassing op vrijstellingen van de prijsaanduiding per eenheid voor voorverpakte producten die door kleine detailhandelaren worden verkocht, als dit een buitensporige last zou vormen?
# English translation: Does this directive allow for exemptions from unit price labeling for pre-packaged products sold by small retail businesses if it would constitute an excessive burden?
# Dutch translation: Wat wordt gewijzigd door Verordening (EG) nr. 1484/2004 van de Commissie?
# English translation: What is being changed by Commission Regulation (EC) No 1484/2004?
# Dutch translation: Waarom was het anti-dumpingrecht op elektronische weegschalen uit Japan verlengd?
# English translation: Why was the anti-dumping duty on electronic weighing scales from Japan extended?
# Dutch translation: Welke specifieke wijzigingen zijn er doorgevoerd in de meeteenheden en hun bijbehorende definities, en wat waren de rechtvaardigingen voor deze veranderingen, zoals uiteengezet in de Richtlijn van de Raad van 18 december 1984 betreffende de onderlinge aanpassing van de wetgevingen van de lidstaten inzake meeteenheden?
# English translation: What specific changes were made to the units of measurement and their associated definitions, and what were the justifications for these alterations, as outlined in the Council Directive of December 18, 1984, concerning the approximation of the laws of the Member States relating to units of measurement?
# Dutch translation: Welke datum geldt de verordening over invoerrechten op granen?
# English translation: From what date does the regulation on import duties on cereals apply?
# Dutch translation: Wat was de vastgestelde wereldprijs, zoals vermeld in artikel 4 van Verordening (EG) nr. 1051/2001, voor ongeëgreneerde katoen, en wat is de eenheid van meting die wordt gebruikt om deze prijs uit te drukken?
# English translation: What is the determined world market price for unginned cotton, as referred to in Article 4 of Regulation (EC) No 1051/2001, and what unit is used to express this price?
# Dutch translation: Een Engelse zoekopdracht: Een Spaans visserijbedrijf dat actief is in ICES-zones VI en VII heeft dit jaar ongewoon hoge vangsten van blauwe leng gerealiseerd, en het juridische team van het bedrijf maakt zich zorgen over mogelijke overbevissing. Ze moeten de huidige regelgeving met betrekking tot de visserij op blauwe leng begrijpen, met name of er recente verboden van kracht zijn die hun activiteiten zouden kunnen beïnvloeden, en zo ja, wat de gevolgen zijn voor hun schepen?
# English translation: A Dutch fishing company operating in ICES zones VI and VII has experienced unusually high catches of blue ling this year, and the company's legal team is concerned about potential overfishing. They need to understand the current regulations regarding blue ling fishing, specifically if there are any recent prohibitions in place that might affect their operations, and if so, what are the implications for their vessels?
# Dutch translation: Een Finse zuivelbedrijf is van plan drinkmelk te exporteren. Ze zijn op de hoogte van specifieke regelgeving met betrekking tot het vetgehalte in melkproducten. Ze willen begrijpen of er speciale bepalingen van toepassing kunnen zijn op hun producten, gezien de productie in Finland. Het bedrijf wil weten of er een tijdelijke uitzondering is op de gebruikelijke eisen voor het vetgehalte van hun drinkmelk, en zo ja, voor welke periode deze uitzondering geldig is, en wat de toegestane bestemmingen voor deze melk zijn onder de uitzondering, met specifieke vermelding van het relevante verordeningsnummer.
# English translation: A Finnish dairy company is planning to export milk for human consumption. They are aware of specific regulations regarding the fat content in milk products. They want to know if there are any special provisions that might apply to their products, considering they are produced in Finland. The company wants to know if there is a temporary exception to the usual fat content requirements for their milk for human consumption, and if so, for what period this exception is valid, and what the permitted destinations for this milk are under the exception, specifically referencing the relevant regulation number.
# Dutch translation: Standaard invoerwaarden voor fruit en groenten vastgesteld door de Commissie.
# English translation: Standard import values for fruit and vegetables established by the Commission.
# Dutch translation: Een varkensboer in Duitsland is van plan varkens uit Hongarije te importeren. Ze zijn op de hoogte van de regelgeving met betrekking tot diergezondheid en de ziekte van Aujeszky. Ze hebben gehoord dat Hongarije bezig is geweest met het bestrijden van deze ziekte. Wat is de huidige status van Hongarije met betrekking tot de ziekte van Aujeszky volgens de laatste updates van de Europese Commissie, en welke bijlage van de relevante beslissing zou deze status weerspiegelen?
# ...
# Dutch translation: Welke militaire uitrusting komt in aanmerking voor douaneschorsing?
# English translation: What military equipment is eligible for duty suspension?
# Dutch translation: Heeft de EU maatregelen voor Madagaskar gewijzigd?
# English translation: Did the EU amend measures for Madagascar?
# Dutch translation: Wat is de Italiaanse interventie-instantie aan het verkopen en wanneer?
# English translation: What is the Italian intervention agency selling and when?
# Dutch translation: Waren importvergunningaanvragen voor knoflook afkomstig uit alle derde landen behalve China voor de periode tussen 1 december 2002 en 28 februari 2003 opgeschort voor nieuwe importeurs na een specifieke datum?
# English translation: Were applications for new importers for certificates for the import of garlic originating from third countries other than China relating to the quarter of December 1st 2002 to February 28th 2003 rejected after a certain date?
# Dutch translation: Welke betaal- en rapportage deadlines zijn gewijzigd voor Franse plantgezondheidsprogramma's?
# English translation: What payment and reporting deadlines have changed for French plant health programs?
# Dutch translation: Een Franse veehouder zoekt in 1984, geconfronteerd met een bevestigde uitbraak van besmettelijke longziekte bij runderen, die leidt tot het afslachten van hun vee, informatie over mogelijke financiële steun om de gemaakte kosten te dekken. Specifiek, welk percentage van de kosten in verband met de compensatie van eigenaren voor het afslachten en vernietigen van runderen, volgend op het verschijnen van deze ziekte, kan de Gemeenschap dekken, en aan welke voorwaarden moet worden voldaan om deze financiële steun te ontvangen?
# English translation: A French livestock farmer, facing a confirmed outbreak of contagious bovine pleuro-pneumonia in 1984, resulting in the slaughter of their cattle, is seeking information on potential financial assistance to cover the incurred costs. Specifically, what percentage of the costs related to compensating owners for the slaughter and destruction of bovine animals, following the appearance of this disease, might the Community cover, and what conditions must be met to receive this financial assistance?
# Dutch translation: Een consultant die de Estse regering adviseert over de EU-toetreding bereidt een rapport voor. De consultant moet het kader begrijpen voor communautaire steun in verband met de pretoetredingsstrategie van Estland. De consultant moet specifiek weten aan welke voorwaarden Estland moet voldoen om deze steun te ontvangen, en welke mechanismen er zijn om de voortgang van Estland bij het voldoen aan deze voorwaarden te monitoren, inclusief de rol van de organen van de Europa-overeenkomst en de Raad. Wat zijn de belangrijkste elementen en processen die hierbij betrokken zijn?
# English translation: A consultant advising the Estonian government on EU accession is preparing a report. The consultant needs to understand the framework for Community assistance related to Estonia's pre-accession strategy. Specifically, the consultant needs to know what conditions Estonia must meet to receive this assistance, and what mechanisms are in place to monitor Estonia's progress in meeting these conditions, including the role of the Europe Agreement bodies and the Council. What are the key elements and processes involved?
# Dutch translation: Een staalverwerkend bedrijf in het Verenigd Koninkrijk wil het juridische kader begrijpen dat de handel in staalproducten tussen de Europese Gemeenschap voor Kolen en Staal en de Russische Federatie regelt. Ze zijn met name geïnteresseerd in de specifieke tijdsperiode waarvoor een overeenkomst met betrekking tot deze handel is verlengd, aangezien ze de implicaties voor hun import- en exportactiviteiten moeten beoordelen. Kunt u de exacte periode aangeven waarvoor de overeenkomst tussen de Europese Gemeenschap voor Kolen en Staal en de Russische Federatie betreffende de handel in bepaalde staalproducten is verlengd, zoals vermeld in relevante juridische documenten?
# English translation: A Dutch steel trader wants to understand the legal aspects of trade in iron and steel products between the European Coal and Steel Community and the Russian Federation. The trader is specifically interested in the period for which an agreement regarding this trade was extended, as this may affect their import and export activities. Could you please indicate the exact period for which the agreement between the European Coal and Steel Community and the Russian Federation concerning trade in certain iron and steel products was extended, as stated in relevant legal documents?
# Dutch translation: Een voertuigfabrikant bereidt zich voor om zijn voertuigmodellen te updaten met nieuwe radartechnologie en moet de specifieke vereisten begrijpen voor het documenteren van de aanwezigheid van kortbereikradarapparatuur. What specific changes were made to the information required on the Certificate of Conformity regarding vehicles equipped with 24 GHz short-range radar equipment, and what was removed?
# English translation: A vehicle manufacturer is preparing to update its vehicle models with new radar technology and needs to understand the specific requirements for documenting the presence of short-range radar equipment. Welke specifieke wijzigingen zijn er aangebracht in de informatie die vereist is op het Certificaat van Overeenstemming met betrekking tot voertuigen die zijn uitgerust met 24 GHz-kortbereikradarapparatuur, en wat is er verwijderd?
# Dutch translation: Roemenië brucellosevrije status voor schapen en geiten?
# English translation: Is Slovenia officially free of bovine brucellosis?
# Dutch translation: Wat is de datum waarop Commission Regulation (EC) No 934/2007, die de standaard invoerwaarden vaststelt voor het bepalen van de toegangsprijs van bepaalde groenten en fruit, in werking treedt volgens het document, en wat is de datum van de vaststelling ervan?
# English translation: On what date does Commission Regulation (EC) No 934/2007, which establishes the standard import values for determining the entry price of certain fruit and vegetables, enter into force according to the document, and what is the date of its adoption?
# Dutch translation: Een Belgisch visbedrijf dat actief is in ICES-sectoren VIII a, b, d en e wateren, ving in 1994 heek. Ze ontvingen informatie van de Belgische overheid over een quotum voor heek. Het bedrijf weet nu niet zeker of ze kunnen doorgaan met het vissen op heek in de gespecificeerde wateren, en zo niet, welke acties verboden zijn. Welke specifieke datum is relevant voor hun visserijactiviteiten, en welke acties mogen ze niet ondernemen als die datum is verstreken?
# English translation: A Belgian fishing company operating in ICES divisions VIII a, b, d and e caught hake in 1994. They received information from the Belgian government about a hake quota. The company is now unsure if they can continue fishing for hake in the specified waters, and if not, what actions are prohibited. What specific date is relevant to their fishing activities, and what actions are they forbidden from taking if that date has passed?
# Dutch translation: Details over witte suiker voedselhulp levering en voorwaarden.
# English translation: Details about the supply and conditions of white sugar food aid.
# Dutch translation: Is de maximale steun voor geconcentreerde boter, gerelateerd aan de 306e bijzondere uitnodiging tot inschrijving onder de permanente uitnodiging tot inschrijving geopend door Verordening (EEG) nr. 429/90, in dit specifieke document bepaald?
# English translation: Is in this specific document the maximum amount of aid and the certainty of destination determined for the 306th special invitation to tender held under the standing invitation to tender as referred to in Regulation (EEC) No 429/90?
# Dutch translation: Is er een project voor snelle datatransmissie aangenomen?
# English translation: Was a high-speed data-transmission project adopted?
# Dutch translation: Zijn de representatieve prijzen voor pluimveevlees importen aangepast?
# English translation: Were the representative prices for poultry meat imports adjusted?
# Dutch translation: Gezien de beslissing van de Veiligheidsraad van de Verenigde Naties over de beperkingen op de handel met de Federale Republiek Joegoslavië (Servië en Montenegro), welke specifieke wijzigingen zijn er aangebracht in de bestaande Gemeenschapswetgeving, en wat is de effectieve duur van deze wijzigingen volgens de Raadsverordening van 23 januari 1995?
# English translation: What specific adjustments to the existing Community legislation were implemented, and from which date to which date are these adjustments applicable, considering the decision of the United Nations Security Council regarding restrictions on trade with the Federal Republic of Yugoslavia (Serbia and Montenegro) as mentioned in the Council Regulation of January 23, 1995?
# Dutch translation: Heeft de Europese Commissie's verordening betreffende uitvoerrestituties voor rijst en breukrijst, specifiek die welke op 1 oktober 2001 in werking trad, de afgifte van uitvoervergunningen met voorafgaande restitutievaststelling voor alle rijstuitvoer opgeschort?
# English translation: Has the issuance of export certificates with advance fixing of the refund for rice and broken rice, except for a specific quantity, been suspended according to the Commission Regulation of September 28, 2001?
# Dutch translation: Zijn de H5N1 maatregelen voor Duitsland of Polen gewijzigd?
# English translation: Did the H5N1 measures change for Germany or Poland?
# Dutch translation: Waren er importvergunningen afgegeven voor rundvlees uit Namibië?
# English translation: Were import certificates issued for beef from Namibia?
# Dutch translation: Standaard invoerwaarden voor fruit en groenten, hoe worden ze bepaald?
# English translation: How are standard import values for fruit and vegetables determined?
# Dutch translation: Wordt in het Engelse document van 4 mei 2006 over representatieve prijzen en aanvullende invoerrechten in de suikersector expliciet de specifieke bedragen voor invoerrechten genoemd als deze worden opgeschort op basis van een bepaalde verordening?
# English translation: Does the Dutch document from May 4, 2006, regarding representative prices and additional import duties in the sugar sector, explicitly mention the specific amounts for import duties if they are suspended according to a particular regulation?
# Dutch translation: Welke specifieke uitgaven die door de lidstaten zijn verricht onder de EAGGF Garantie-afdeling worden uitgesloten van communautaire financiering volgens de beschikking van de Commissie van 16 juli 2004, en waarom worden deze uitgaven uitgesloten?
# English translation: What specific expenditures incurred by Member States under the EAGGF Guarantee Section are excluded from Community financing according to the Commission Decision of July 16, 2004, and why are these expenditures excluded?
# Dutch translation: Is de visserij op haring in de wateren van ICES-sectoren IV c (behalve Blackwater-bestand) en VII d door vaartuigen die de Deense vlag voeren of in Denemarken geregistreerd zijn, verboden, evenals het aan boord houden, overladen en aanlanden van die voorraad gevangen door bovengenoemde vaartuigen na een specifieke datum?
# English translation: Has fishing for herring in the waters of ICES divisions IV c (except Blackwater stock) and VII d by vessels flying the flag of Denmark or registered in Denmark been prohibited, as well as the retention on board, transhipment, and landing of that stock captured by the abovementioned vessels after a specific date?
# Dutch translation: Een bedrijf dat gespecialiseerd is in de opslag van landbouwproducten bereidt zijn jaarrekening voor het marketingjaar 2005/2006 voor. Ze hebben een grote hoeveelheid gedroogde druiven en gedroogde vijgen opgeslagen. Het bedrijf moet de opslagsteun waar ze recht op hebben nauwkeurig berekenen volgens de relevante regelgeving. Specifiek, wat is het exacte bedrag aan opslagsteun, per dag en per ton netto gewicht, dat ze kunnen claimen voor gedroogde druiven opgeslagen vanaf het begin van het marketingjaar tot 28 februari 2007, en vervolgens vanaf 1 maart 2007, en wat is de opslagsteun voor gedroogde vijgen?
# English translation: A storage company for agricultural products is preparing its annual accounts for the 2005/2006 sales season. They have stored a large quantity of currants, raisins and dried figs. The company needs to accurately calculate the storage aid they are entitled to, based on the relevant regulations. What exactly is the amount of storage aid, per day and per tonne net weight, that the company can claim for currants and raisins stored from the beginning of the sales season up to and including February 28, 2007, and then from March 1, 2007, and what is the storage aid for dried figs?
# Dutch translation: Invoerregels voor siervissen, weekdieren, schaaldieren?
# English translation: Import rules for ornamental fish, molluscs, crustaceans?
# Dutch translation: Welke conclusies werden getrokken over de absorptie van anti-dumpingrechten op de invoer van siliciummetaal uit China, inclusief het specifieke percentage en de daaruit voortvloeiende maatregelen van de Raad?
# English translation: What were the findings regarding the absorption of anti-dumping duty on silicon metal imports from China, including the specific percentage and the resulting actions taken by the Council?
# Dutch translation: Wat zijn de technische specificaties voor biometrische kenmerken in het VIS?
# English translation: What are the technical specifications for biometric features in the VIS?
# Dutch translation: Een Duitse tabaksboer in 1990, actief in de voormalige Duitse Democratische Republiek, zoekt informatie over de mogelijkheden om financiële steun te ontvangen voor zijn tabaksoogst. Hij is zich ervan bewust dat de eenwording van Duitsland een unieke situatie heeft gecreëerd met betrekking tot landbouwvoorschriften. Specifiek, welke bepalingen, indien van toepassing, werden getroffen om Duitsland in staat te stellen betalingen te verrichten voor prijzen, premies en uitvoerrestituties voor tabak die in 1990 in de voormalige Duitse Democratische Republiek werd geoogst, en welke beperkingen of voorwaarden werden aan deze betalingen gesteld om eerlijke concurrentie binnen de bredere Europese Economische Gemeenschap te waarborgen?
# English translation: A German tobacco farmer in 1990, active in the former German Democratic Republic, is seeking information about the possibilities of receiving financial support for their tobacco harvest. They are aware that the unification of Germany has created a unique situation regarding agricultural regulations. Specifically, what provisions, if any, were put in place to allow Germany to make payments for prices, premiums, and export refunds for tobacco harvested in the former German Democratic Republic in 1990, and what limitations or conditions were imposed on these payments to ensure fair competition within the broader European Economic Community?
# Dutch translation: Gezien de export van producten uit de wijnsector, was het percentage van de aangevraagde hoeveelheden waarvoor uitvoercertificaten met voorafgaande vaststelling van de restitutie werden afgegeven, hetzelfde voor zowel Afrika als Oost-Europa, volgens de Verordening van de Commissie van 14 juni 2001?
# English translation: Considering the export of wine sector products, did the Commission Regulation of June 14, 2001, set the same percentage of requested quantities for the issuance of export licenses with advance fixing of the refund for both Africa and Eastern Europe?

# %%
# manual check

few_translations = stratified_sample.sample(n=20)

for row in few_translations.values:
    print(row[7])
    print()
    print(row[11])
    print()
    print()
    print(row[8])
    print()
    print(row[12])
    print()
    print()
# Out:
# A fruit importer is planning to bring in a large shipment of fresh sour cherries from the former Yugoslav Republic of Macedonia. They are unsure about the specific requirements and procedures they need to follow to ensure the import complies with all relevant regulations. What specific documentation and steps are required, and what are the potential financial implications if the import is not completed within a certain timeframe?
#
# A fruit importer wants to import a large shipment of fresh sour cherries from the former Yugoslav Republic of Macedonia. They are unsure about the specific requirements and procedures they need to follow to ensure the import complies with all relevant regulations. What specific documentation and steps are required, and what are the potential financial consequences if the import is not completed within a certain timeframe?
#
#
# Een fruitimporteur wil een grote zending verse zure kersen uit de voormalige Joegoslavische Republiek Macedonië importeren. Ze zijn onzeker over de specifieke vereisten en procedures die ze moeten volgen om ervoor te zorgen dat de import voldoet aan alle relevante voorschriften. Welke specifieke documentatie en stappen zijn vereist, en wat zijn de mogelijke financiële gevolgen als de import niet binnen een bepaalde termijn wordt voltooid?
#
# Een fruitimporteur plant een grote zending verse zure kersen uit de voormalige Joegoslavische Republiek Macedonië te importeren. Ze zijn onzeker over de specifieke vereisten en procedures die ze moeten volgen om ervoor te zorgen dat de import voldoet aan alle relevante regelgeving. Welke specifieke documentatie en stappen zijn vereist, en wat zijn de mogelijke financiële gevolgen als de import niet binnen een bepaalde termijn is voltooid?
#
#
#
# What is the date that Commission Regulation (EC) No 934/2007, which establishes the standard import values for determining the entry price of certain fruit and vegetables, enters into force according to the document, and what is the date of its adoption?
#
# On what date does Commission Regulation (EC) No 934/2007, which establishes the standard import values for determining the entry price of certain fruit and vegetables, enter into force according to the document, and what is the date of its adoption?
#
#
# Op welke datum treedt de Verordening (EG) Nr. 934/2007 van de Commissie, die forfaitaire invoerwaarden voor de bepaling van de invoerprijzen van bepaalde soorten groenten en fruit vaststelt, in werking volgens het document, en wat is de datum waarop deze verordening is vastgesteld?
#
# Wat is de datum waarop Commission Regulation (EC) No 934/2007, die de standaard invoerwaarden vaststelt voor het bepalen van de toegangsprijs van bepaalde groenten en fruit, in werking treedt volgens het document, en wat is de datum van de vaststelling ervan?
#
#
#
# Criteria for allocating additional milk reference quantities in Denmark.
#
# Criteria for allocating additional milk reference quantities in Denmark.
#
#
# Criteria voor toewijzing extra melk referentiehoeveelheden in Denemarken.
#
# Criteria for allocating additional milk reference quantities in Denmark.
#
#
#
# Is the introduction of certain species suspended?
#
# Is the introduction of certain species suspended?
#
#
# Wordt het binnenbrengen van bepaalde soorten geschorst?
#
# Is de introductie van bepaalde soorten opgeschort?
#
#
#
# Considering the Commission Decision of February 13, 2002, which addresses measures against the pinewood nematode, is the deadline for the measures outlined in Article 2 of Decision 2001/218/EC extended to February 28, 2003?
#
# Considering the Commission Decision of February 13, 2002, which addresses measures against the pinewood nematode, is the deadline for the measures outlined in Article 2 of Decision 2001/218/EC extended to February 28, 2003?
#
#
# Gezien de Beschikking van de Commissie van 13 februari 2002 over maatregelen tegen het dennenaaltje, wordt de termijn voor de maatregelen beschreven in Artikel 2 van Beschikking 2001/218/EG verlengd tot 28 februari 2003?
#
# Gezien de zoekopdracht: "Considering the Commission Decision of February 13, 2002, which addresses measures against the pinewood nematode, is the deadline for the measures outlined in Article 2 of Decision 2001/218/EC extended to February 28, 2003?"
#
#
#
# Does the Commission Regulation (EC) No 591/2007, which fixes representative prices in the poultrymeat and egg sectors and for egg albumin, explicitly state that it amends the representative prices for imports of certain products, and if so, does it also mention the need to publish these amended prices?
#
# Does the Dutch query ask whether Commission Regulation (EC) No 591/2007, which sets representative prices in the poultrymeat and egg sectors and for egg albumin, explicitly mentions that it amends the representative prices for imports of certain products, and if so, whether it also mentions the need to publish these amended prices?
#
#
# Worden in de Verordening (EG) Nr. 591/2007 van de Commissie, die de representatieve prijzen in de sectoren slachtpluimvee en eieren, alsmede van ovoalbumine vaststelt, de representatieve prijzen voor de invoer van bepaalde producten gewijzigd, en zo ja, wordt de noodzaak om deze gewijzigde prijzen te publiceren ook vermeld?
#
# Wordt in de Engelse zoekopdracht gevraagd of de Commissieverordening (EG) Nr. 591/2007, die de representatieve prijzen in de sectoren pluimveevlees en eieren en voor ei-albumine vaststelt, expliciet vermeldt dat zij de representatieve prijzen voor de invoer van bepaalde producten wijzigt, en zo ja, of er ook wordt vermeld dat deze gewijzigde prijzen moeten worden gepubliceerd?
#
#
#
# A Polish fishing company operating in the NAFO zone 3L has been informed that their catches of northern prawn have been substantial. They are concerned about potential legal repercussions. What actions are prohibited for vessels flying the flag of Poland, or registered in Poland, regarding the fishing of northern prawn in NAFO zone 3L, and from what date do these prohibitions become effective, according to any relevant regulations? The company needs to understand the specific restrictions and the exact date from which they apply to ensure compliance and avoid penalties.
#
# A Polish fishing company operating in NAFO zone 3L has been informed that their catches of northern shrimp have been substantial. They are concerned about potential legal repercussions. What actions are prohibited for vessels flying the Polish flag, or registered in Poland, regarding the fishing of northern shrimp in NAFO zone 3L, and from what date do these prohibitions become effective, according to relevant regulations? The company needs to understand the specific restrictions and the exact date from which they apply to ensure compliance and avoid penalties.
#
#
# Een Pools visserijbedrijf dat actief is in NAFO-gebied 3L is geïnformeerd dat hun vangsten van Noordse garnaal aanzienlijk zijn geweest. Ze maken zich zorgen over mogelijke juridische gevolgen. Welke acties zijn verboden voor vaartuigen die de vlag van Polen voeren, of in Polen geregistreerd zijn, met betrekking tot de visserij op Noordse garnaal in NAFO-gebied 3L, en vanaf welke datum worden deze verboden van kracht, volgens eventuele relevante verordeningen? Het bedrijf moet de specifieke beperkingen en de exacte datum waarop deze van toepassing zijn begrijpen om naleving te garanderen en boetes te voorkomen.
#
# Een Pools visserijbedrijf dat actief is in NAFO-zone 3L is geïnformeerd dat hun vangsten van noordse garnaal aanzienlijk zijn geweest. Ze maken zich zorgen over mogelijke juridische gevolgen. Welke acties zijn verboden voor vaartuigen die de Poolse vlag voeren, of in Polen geregistreerd zijn, met betrekking tot de visserij op noordse garnaal in NAFO-zone 3L, en vanaf welke datum worden deze verboden van kracht, volgens relevante regelgeving? Het bedrijf moet de specifieke beperkingen en de exacte datum waarop deze van toepassing zijn begrijpen om naleving te garanderen en boetes te voorkomen.
#
#
#
# Did butter storage rules change regarding direct consumption aid?
#
# Have the butter storage rules changed?
#
#
# Zijn de regels voor roomopslag gewijzigd?
#
# Zijn de regels voor boteropslag gewijzigd met betrekking tot directe consumptie?
#
#
#
# Does the Commission Regulation of June 30, 1993, concerning the Canary Islands and breeding rabbits, introduce any changes to the Annex of a previous regulation regarding the same subject matter?
#
# Does the Dutch query ask if the Commission Regulation of June 30, 1993, concerning the Canary Islands and breeding rabbits, introduces changes to the annex of a previous regulation on the same subject?
#
#
# Worden er door de Commissieverordening van 30 juni 1993 betreffende de Canarische eilanden en fokkonijnen wijzigingen aangebracht in de bijlage van een eerdere verordening over hetzelfde onderwerp?
#
# Wordt er in de Engelse zoekopdracht gevraagd of de Commissieverordening van 30 juni 1993, betreffende de Canarische Eilanden en fokkonijnen, wijzigingen introduceert in de bijlage van een eerdere verordening over hetzelfde onderwerp?
#
#
#
# What specific agricultural products from the Canary Islands were subject to quantitative restrictions on import into Portugal, and until what dates were these restrictions allowed to be maintained, according to the Council Regulation from February 1986, and what were the initial quota rules?
#
# What specific agricultural products from the Canary Islands were subject to quantitative restrictions on import into Portugal, and until what dates were these restrictions allowed to be maintained, according to the Council Regulation from February 1986, and what were the initial quota rules?
#
#
# Welke specifieke landbouwproducten van de Canarische eilanden waren onderworpen aan kwantitatieve beperkingen bij invoer in Portugal, tot welke data mochten deze beperkingen worden gehandhaafd volgens de Raadsverordening van februari 1986, en wat waren de regels voor het oorspronkelijke contingent?
#
# Welke specifieke landbouwproducten van de Canarische eilanden waren onderworpen aan kwantitatieve beperkingen bij invoer in Portugal, en tot welke data mochten deze beperkingen worden gehandhaafd, volgens de Raadsverordening van februari 1986, en wat waren de regels voor het oorspronkelijke contingent?
#
#
#
# What was the estimated unginned cotton production for Greece and Spain in 1996/97?
#
# Wat was de geraamde productie van niet-geëgreneerde katoen voor Griekenland en Spanje in 1996/1997?
#
#
# Wat was de geraamde productie van niet-geëgreneerde katoen voor Griekenland en Spanje in 1996/1997?
#
# What was the estimated unginned cotton production for Greece and Spain in 1996/97?
#
#
#
# How is durum wheat aid affected outside traditional zones?
#
# How is support for durum wheat affected outside traditional zones?
#
#
# Hoe wordt steun voor durumtarwe buiten traditionele zones geregeld?
#
# Hoe is de hulp voor durumtarwe buiten traditionele zones beïnvloed?
#
#
#
# What was the increased maximum number of days at sea for vessels flying the flag of France that were authorized to be present in ICES divisions VIIIc and IXa excluding the Gulf of Cadiz, according to this document?
#
# How many extra sea days were granted to France for fishing vessels that had definitively ceased their fishing activities between February 1, 2004 and January 31, 2010, according to this implementing decision?
#
#
# Hoeveel extra zeedagen werden er toegekend aan Frankrijk voor vissersvaartuigen die hun visserijactiviteiten definitief hadden beëindigd tussen 1 februari 2004 en 31 januari 2010, volgens dit uitvoeringsbesluit?
#
# Wat was het verhoogde maximum aantal dagen op zee voor vaartuigen die de Franse vlag voerden en die toestemming hadden om aanwezig te zijn in ICES-divisies VIIIc en IXa, met uitzondering van de Golf van Cadiz, volgens dit document?
#
#
#
# What fishing opportunities are fixed by this regulation?
#
# What catch opportunities are fixed by this regulation?
#
#
# Welke vangstmogelijkheden worden door deze verordening vastgesteld?
#
# Welke fishing opportunities worden door deze verordening vastgesteld?
#
#
#
# A small food producer in Italy wants to market a new type of cured ham, emphasizing its traditional production methods. They've heard about a "Register of certificates of specific character" and the "traditional speciality guaranteed" endorsement. They are unsure how to proceed and what steps are needed to protect the name of their ham and use the endorsement. What is the legal framework that governs the registration of names for agricultural products and foodstuffs, and what are the key requirements and procedures, including the role of the "Register of certificates of specific character" and the "traditional speciality guaranteed" endorsement, that this producer needs to understand to potentially register their ham's name and use the endorsement?
#
# A small food producer in the Netherlands wants to market a new type of cheese, emphasizing the traditional production methods. They have heard about the "Register of Specificity Certification" and the "guaranteed traditional specialty" designation. They are unsure how to proceed and what steps are needed to protect the name of their cheese and use the designation. What legal frameworks apply to the registration of names for agricultural products and foodstuffs, and what are the key requirements and procedures, including the role of the "Register of Specificity Certification" and the "guaranteed traditional specialty" designation, that this producer needs to understand in order to potentially register the name of their cheese and use the designation?
#
#
# Een kleine voedselproducent in Nederland wil een nieuw type kaas op de markt brengen, waarbij de nadruk ligt op de traditionele productiemethoden. Ze hebben gehoord over het "Specificiteitscertificeringsregister" en de vermelding "gegarandeerde traditionele specialiteit". Ze zijn onzeker over hoe ze te werk moeten gaan en welke stappen nodig zijn om de naam van hun kaas te beschermen en de vermelding te gebruiken. Welke wettelijke kaders zijn van toepassing op de registratie van namen voor landbouwproducten en levensmiddelen, en wat zijn de belangrijkste vereisten en procedures, inclusief de rol van het "Specificiteitscertificeringsregister" en de vermelding "gegarandeerde traditionele specialiteit", die deze producent moet begrijpen om mogelijk de naam van hun kaas te registreren en de vermelding te gebruiken?
#
# Een kleine voedselproducent in Italië wil een nieuw type gedroogde ham op de markt brengen, waarbij de nadruk ligt op de traditionele productiemethoden. Ze hebben gehoord over het "Register van certificaten van specifieke karakteristiek" en de vermelding "traditionele specialiteit gegarandeerd". Ze zijn onzeker over hoe te werk te gaan en welke stappen nodig zijn om de naam van hun ham te beschermen en de vermelding te gebruiken. Wat is het wettelijk kader dat de registratie van namen voor landbouwproducten en levensmiddelen regelt, en wat zijn de belangrijkste vereisten en procedures, inclusief de rol van het "Register van certificaten van specifieke karakteristiek" en de vermelding "traditionele specialiteit gegarandeerd", die deze producent moet begrijpen om mogelijk de naam van hun ham te registreren en de vermelding te gebruiken?
#
#
#
# When did the EEC start using coffee origin certificates with quotas?
#
# From which date did the EEC start using coffee origin certificates with quotas?
#
#
# Vanaf welke datum werden koffie-oorsprongcertificaten met quota gebruikt?
#
# Wanneer begon de EEG koffie-oorsprongcertificaten met quota te gebruiken?
#
#
#
# What standard forms are specified for use by contracting entities when publishing notices in the Official Journal of the European Union related to articles 41 to 44 and 63 of Directive 2004/17/EC?
#
# What standard forms must contracting entities use for the publication in the Official Journal of the European Union of notices relating to articles 41 to 44 and 63 of Directive 2004/17/EC?
#
#
# Welke standaardformulieren moeten aanbestedende diensten gebruiken voor de bekendmaking in het Publicatieblad van de Europese Unie van aankondigingen die betrekking hebben op de artikelen 41 tot en met 44 en 63 van Richtlijn 2004/17/EG?
#
# Welke standaardformulieren zijn gespecificeerd voor gebruik door aanbestedende diensten bij het publiceren van aankondigingen in het Publicatieblad van de Europese Unie met betrekking tot de artikelen 41 tot en met 44 en 63 van Richtlijn 2004/17/EG?
#
#
#
# What specific changes were made to the export refunds for white sugar and raw sugar exported in their natural state, and what document or regulation was used to initially set these refunds before this alteration, according to the Commission's regulation?
#
# What specific changes were made to the export refunds for white and raw sugar exported in their natural state, and what document or regulation was used to initially set these refunds before this alteration, according to the Commission's regulation?
#
#
# Welke specifieke wijzigingen zijn aangebracht in de restituties bij uitvoer van witte en ruwe suiker in onveranderde vorm, en welke verordening werd gebruikt om deze restituties aanvankelijk vast te stellen voordat deze wijziging plaatsvond, volgens de verordening van de Commissie?
#
# Welke specifieke wijzigingen zijn aangebracht in de exportrestituties voor witte suiker en ruwe suiker geëxporteerd in hun natuurlijke staat, en welk document of welke verordening werd gebruikt om deze restituties initieel vast te stellen vóór deze wijziging, volgens de verordening van de Commissie?
#
#
#
# What information is required in applications for financing fisheries aid?
#
# What information must be included in applications for fisheries aid?
#
#
# Welke informatie moet in aanvragen voor visserijsteun staan?
#
# Welke informatie is vereist in aanvragen voor financiering van visserijsteun?
#
#
#
# A French beekeeper is seeking information about the legal protection of their honey product, "Miel des Cévennes." They want to know if this honey has been officially recognized and registered, and if so, what specific designation or protection it has been granted. Can you provide details on whether the name "Miel des Cévennes" has been entered into a register, and if so, what type of protection it has received according to the relevant European Union regulations?
#
# A French beekeeper is looking for information about the legal protection of his honey product, "Miel des Cévennes." He wants to know if this honey is officially recognized and registered, and if so, what specific designation or protection it has been granted. Can you provide details on whether the name "Miel des Cévennes" has been entered in a register, and if so, what protection it has received according to the relevant European Union regulations?
#
#
# Een Franse imker wil informatie over de juridische bescherming van zijn honingproduct, "Miel des Cévennes." Hij wil weten of deze honing officieel is erkend en geregistreerd, en zo ja, welke specifieke aanduiding of bescherming hem is verleend. Kunt u details verstrekken over de vraag of de benaming "Miel des Cévennes" is ingeschreven in een register, en zo ja, welke bescherming deze heeft gekregen volgens de relevante Europese Unie-verordeningen?
#
# Een Franse imker zoekt informatie over de juridische bescherming van zijn honingproduct, "Miel des Cévennes." Hij wil weten of deze honing officieel erkend en geregistreerd is, en zo ja, welke specifieke aanduiding of bescherming het heeft gekregen. Kunt u details verstrekken over de vraag of de naam "Miel des Cévennes" in een register is opgenomen, en zo ja, welke bescherming het heeft ontvangen volgens de relevante Europese Unie-voorschriften?

# %%
# save the new dataframe so it can be used as input in notebook 4_BM25_application_evaluation

stratified_sample.to_csv('data/stratified_sample_with_translated_queries.csv', index=False)
